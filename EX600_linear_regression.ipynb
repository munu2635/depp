# %%
import tensorflow as tf

x_data = [1, 2, 3, 4]
y_data = [2, 4, 6, 8]

W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.random_uniform([1], -1.0, 1.0))

X = tf.placeholder(tf.float32, name="X")
Y = tf.placeholder(tf.float32, name="Y")

hypothesis = W * X + b

cost = tf.reduce_mean(tf.square(hypothesis - Y))

optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.1)

train_op = optimizer.minimize(cost)


with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())

    for step in range(100):
        _, cost_val = sess.run([train_op, cost], feed_dict={X: x_data, Y: y_data})

        print(step, cost_val, sess.run(W), sess.run(b))


    print("\n=== Test ===")
    print("X: 5, Y:", sess.run(hypothesis, feed_dict={X: 5}))
    print("X: 2.5, Y:", sess.run(hypothesis, feed_dict={X: 2.5}))
# Out:
# 0 62.6726 [ 3.62857032] [ 0.91179943]
# 1 28.1478 [ 0.72981524] [-0.08484554]
# 2 12.6463 [ 2.67751503] [ 0.56721592]
# 3 5.68592 [ 1.37763453] [ 0.11501521]
# 4 2.56036 [ 2.25367522] [ 0.40319493]
# 5 1.1566 [ 1.67156482] [ 0.19571832]
# 6 0.525924 [ 2.06635857] [ 0.32079226]
# 7 0.24237 [ 1.80642462] [ 0.22345454]
# 8 0.114691 [ 1.98506045] [ 0.27555132]
# 9 0.0570194 [ 1.86969399] [ 0.22791082]
# 10 0.0308 [ 1.9511975] [ 0.24748163]
# 11 0.0187212 [ 1.9006604] [ 0.22238654]
# 12 0.0130095 [ 1.93847656] [ 0.22757906]
# 13 0.0101735 [ 1.91697216] [ 0.21282496]
# 14 0.00864466 [ 1.93510151] [ 0.2117739]
# 15 0.00771776 [ 1.92656231] [ 0.20186837]
# 16 0.0070753 [ 1.93578458] [ 0.19821352]
# 17 0.00657393 [ 1.93300092] [ 0.19067851]
# 18 0.00614844 [ 1.9381603] [ 0.18604235]
# 19 0.00576887 [ 1.93789864] [ 0.17975374]
# 20 0.00542099 [ 1.94117379] [ 0.17485367]
# 21 0.00509783 [ 1.9419862] [ 0.16929601]
# 22 0.00479562 [ 1.94435894] [ 0.16444373]
# 23 0.00451209 [ 1.94559872] [ 0.15937552]
# 24 0.00424563 [ 1.94751287] [ 0.15470104]
# 25 0.00399508 [ 1.94889295] [ 0.15000436]
# 26 0.00375938 [ 1.95055139] [ 0.14555703]
# 27 0.00353763 [ 1.95194578] [ 0.14116994]
# 28 0.00332896 [ 1.9534421] [ 0.13696304]
# 29 0.00313261 [ 1.95479751] [ 0.1328494]
# 30 0.00294784 [ 1.95617664] [ 0.1288808]
# 31 0.00277396 [ 1.95747125] [ 0.1250163]
# 32 0.00261036 [ 1.95875621] [ 0.12127742]
# 33 0.00245638 [ 1.95998323] [ 0.11764386]
# 34 0.00231151 [ 1.96118641] [ 0.11412347]
# 35 0.00217517 [ 1.96234512] [ 0.11070558]
# 36 0.00204688 [ 1.96347475] [ 0.10739194]
# 37 0.00192614 [ 1.96456671] [ 0.10417619]
# 38 0.00181254 [ 1.96562862] [ 0.10105762]
# 39 0.00170563 [ 1.96665692] [ 0.0980318]
# 40 0.00160503 [ 1.96765554] [ 0.09509695]
# 41 0.00151036 [ 1.96862376] [ 0.09224979]
# 42 0.00142127 [ 1.96956325] [ 0.08948795]
# 43 0.00133745 [ 1.97047436] [ 0.08680873]
# 44 0.00125857 [ 1.97135842] [ 0.08420979]
# 45 0.00118433 [ 1.97221589] [ 0.08168861]
# 46 0.00111448 [ 1.97304785] [ 0.07924296]
# 47 0.00104874 [ 1.97385454] [ 0.07687041]
# 48 0.000986888 [ 1.97463751] [ 0.07456905]
# 49 0.000928677 [ 1.97539663] [ 0.07233647]
# 50 0.000873902 [ 1.97613335] [ 0.07017083]
# 51 0.000822361 [ 1.97684789] [ 0.06806998]
# 52 0.000773854 [ 1.97754109] [ 0.06603204]
# 53 0.000728215 [ 1.97821343] [ 0.06405509]
# 54 0.000685263 [ 1.97886574] [ 0.06213735]
# 55 0.000644843 [ 1.97949851] [ 0.06027703]
# 56 0.000606813 [ 1.9801122] [ 0.05847236]
# 57 0.000571019 [ 1.98070776] [ 0.05672181]
# 58 0.000537341 [ 1.98128521] [ 0.05502357]
# 59 0.000505643 [ 1.98184562] [ 0.05337624]
# 60 0.000475821 [ 1.98238909] [ 0.0517782]
# 61 0.000447755 [ 1.98291636] [ 0.050228]
# 62 0.000421349 [ 1.98342776] [ 0.0487242]
# 63 0.000396495 [ 1.98392403] [ 0.04726549]
# 64 0.000373106 [ 1.98440528] [ 0.04585038]
# 65 0.000351102 [ 1.98487222] [ 0.0444777]
# 66 0.000330395 [ 1.9853251] [ 0.04314608]
# 67 0.000310908 [ 1.98576438] [ 0.04185429]
# 68 0.000292567 [ 1.98619068] [ 0.04060125]
# 69 0.00027531 [ 1.98660409] [ 0.03938568]
# 70 0.000259073 [ 1.98700511] [ 0.0382065]
# 71 0.000243792 [ 1.98739421] [ 0.03706265]
# 72 0.000229418 [ 1.98777151] [ 0.035953]
# 73 0.000215884 [ 1.98813772] [ 0.03487664]
# 74 0.000203149 [ 1.98849273] [ 0.03383242]
# 75 0.000191167 [ 1.98883736] [ 0.03281957]
# 76 0.000179892 [ 1.9891715] [ 0.03183695]
# 77 0.000169283 [ 1.98949575] [ 0.0308838]
# 78 0.000159298 [ 1.98981023] [ 0.02995917]
# 79 0.000149902 [ 1.99011528] [ 0.0290622]
# 80 0.000141059 [ 1.99041128] [ 0.02819212]
# 81 0.00013274 [ 1.99069834] [ 0.02734807]
# 82 0.000124911 [ 1.99097681] [ 0.02652929]
# 83 0.000117544 [ 1.99124694] [ 0.02573502]
# 84 0.000110612 [ 1.99150908] [ 0.02496457]
# 85 0.000104087 [ 1.99176311] [ 0.02421708]
# 86 9.79479e-05 [ 1.99200988] [ 0.0234921]
# 87 9.21703e-05 [ 1.99224889] [ 0.02278872]
# 88 8.67346e-05 [ 1.99248123] [ 0.02210655]
# 89 8.16191e-05 [ 1.99270606] [ 0.02144461]
# 90 7.68041e-05 [ 1.99292457] [ 0.02080264]
# 91 7.22753e-05 [ 1.99313641] [ 0.02017984]
# 92 6.80112e-05 [ 1.99334192] [ 0.01957569]
# 93 6.39998e-05 [ 1.99354124] [ 0.01898961]
# 94 6.02252e-05 [ 1.9937346] [ 0.01842108]
# 95 5.66738e-05 [ 1.99392211] [ 0.01786953]
# 96 5.33316e-05 [ 1.99410415] [ 0.01733457]
# 97 5.01845e-05 [ 1.9942807] [ 0.01681561]
# 98 4.72241e-05 [ 1.99445188] [ 0.01631216]
# 99 4.44408e-05 [ 1.99461794] [ 0.01582378]
#
# === Test ===
# X: 5, Y: [ 9.98891258]
# X: 2.5, Y: [ 5.00236845]
